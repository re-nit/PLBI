# %%
import pandas as pd
import numpy as np
df_pmi = pd.read_csv(r"C:\Users\KHATERINE\PACMANN\PLBI\PLBI\Laporan Gudang Darurat PMI (s.d. 27 April 2021).csv")
df_pmi = df_pmi[df_pmi["Tanggal"].notna()]
df_pmi
# Out:
#         Tanggal IN / OUT Nomor GDN/GRN Gudang             Dari/Kepada-Masking  \
# 0     01-Feb-20       IN          1.01     G2      Gudang Regional PMI_Serang
# 1     01-Feb-20      OUT          1.01     G2                      Ketua Umum
# 2     01-Feb-20      OUT          1.02     G2            PMI Kabupaten Natuna
# 3     05-Feb-20      OUT          5.01     G2           Palang Merah Hongkong
# 4     05-Feb-20      OUT          5.02     G2                       Lain-lain
# ...         ...      ...           ...    ...                             ...
# 8184  26-Apr-21      OUT             -     G4  Tidak Layak digunakan (Reject)
# 8185  26-Apr-21      OUT             -     G4  Tidak Layak digunakan (Reject)
# 8186  26-Apr-21      OUT             -     G4  Tidak Layak digunakan (Reject)
# 8187  27-Apr-21      OUT         27.01     G4                    Staff MP PMI
# 8188  27-Apr-21      OUT         27.01     G4                    Staff MP PMI
#
# ...
